# %%
import re

# %%
my_folder = "C\desktop\notes"
print(my_folder)
# Out:
# C\desktop
# otes

# %%
my_folder = r"C\desktop\notes"
print(my_folder)
# Out:
# C\desktop\notes

# %%
pattern_result = re.search('pattern',r"This is a sample text to search the pattern")
print(pattern_result)
# Out:
# <re.Match object; span=(36, 43), match='pattern'>

# %%
print(pattern_result.group())
# Out:
# pattern

# %%
pattern_result = re.search('pattern',r"This is a sample text to search")
print(pattern_result)
# Out:
# None

# %%
string = r"sara was able to help me find the items i needed quickly"
re.sub(r'sara',r'sarah',string)
# Out:
# 'sarah was able to help me find the items i needed quickly'

# %%
customer_reviews = ['sam was a great help to me in the store', 
                    'the cashier was very rude to me, I think her name was eleanor', 
                    'amazing work from sadeen!', 
                    'sarah was able to help me find the items i neeed quickly', 
                    'lucy is such a great addition to the team', 
                    'great service from sara she found me what i wanted',
                    'great service from sar she found me what i wanted'
                   ]

# %%
pattern = r"sarah?"

# %%
sarah_reviews = []

# %%
for review in customer_reviews:
    if re.search(pattern, review):
        sarah_reviews.append(review)

# %%
print(sarah_reviews)
# Out:
# ['sarah was able to help me find the items i neeed quickly', 'great service from sara she found me what i wanted']

# %%
pattern = r"sara?h?"
sarah_reviews = []
for review in customer_reviews:
    if re.search(pattern, review):
        sarah_reviews.append(review)
print(sarah_reviews)
# Out:
# ['sarah was able to help me find the items i neeed quickly', 'great service from sara she found me what i wanted', 'great service from sar she found me what i wanted']

# %%
a_reviews = []
pattern_to_find = r"^a"
for string in customer_reviews:
    if (re.search(pattern_to_find, string)):
        a_reviews.append(string)
print(a_reviews)
# Out:
# ['amazing work from sadeen!']

# %%
y_reviews = []
pattern_to_find = r"y$"

# %%
for string in customer_reviews:
    if (re.search(pattern_to_find, string)):
        y_reviews.append(string)
print(y_reviews)
# Out:
# ['sarah was able to help me find the items i neeed quickly']

# %%
needwant_reviews = []
pattern_to_find = r"(need|want)ed"

# %%
for string in customer_reviews:
    if (re.search(pattern_to_find, string)):
        needwant_reviews.append(string)

# %%
print(needwant_reviews)
# Out:
# ['great service from sara she found me what i wanted', 'great service from sar she found me what i wanted']

# %%
no_punct_reviews = []
pattern_to_find = r"[^\w\s]"

# %%
for string in customer_reviews:
    no_punct_string = re.sub(pattern_to_find, "", string)
    no_punct_reviews.append(no_punct_string)

# %%
print(no_punct_reviews)
# Out:
# ['sam was a great help to me in the store', 'the cashier was very rude to me I think her name was eleanor', 'amazing work from sadeen', 'sarah was able to help me find the items i neeed quickly', 'lucy is such a great addition to the team', 'great service from sara she found me what i wanted', 'great service from sar she found me what i wanted']
