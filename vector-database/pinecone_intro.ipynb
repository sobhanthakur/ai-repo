# %%
import pinecone
from pinecone import Pinecone, ServerlessSpec
import os
from dotenv import load_dotenv, find_dotenv

# %%
load_dotenv(find_dotenv(), override = True)
# Out:
# True

# %%
pc = Pinecone(
    api_key=os.environ.get("PINECONE_API_KEY")
)

# %%
pc.list_indexes()
# Out:
# IndexList([<name='my-index', dim=3, ready=True>])

# %%
index_name = "my-index"
dimension = 3
metric = "cosine"

# %%
if index_name in [index.name for index in pc.list_indexes()]:
    pc.delete_index(index_name)
    print(f"{index_name} succesfully deleted.")
else:
     print(f"{index_name} not in index list.")
# Out:
# my-index succesfully deleted.

# %%
pc.list_indexes()
# Out:
# IndexList([])

# %%
pc.create_index(
    name = index_name, 
    dimension = dimension, 
    metric = metric, 
    spec = ServerlessSpec(
        cloud = "aws", 
        region = "us-east-1")
    )
# Out:
# IndexModel(name='my-index', metric='cosine', status=IndexStatus(ready=True, state='Ready'), spec=IndexSpec(serverless=ServerlessSpecInfo(cloud='aws', region='us-east-1', read_capacity={'mode': 'OnDemand', 'status': {'state': 'Ready', 'current_shards': None, 'current_replicas': None}}, source_collection=None, schema=None), pod=None, byoc=None), host='https://my-index-4l0pdu7.svc.aped-4627-b74a.pinecone.io', private_host=None, vector_type='dense', dimension=3, deletion_protection='disabled', tags=None, embed=None, created_at=None)

# %%
pc.list_indexes()
# Out:
# IndexList([<name='my-index', dim=3, ready=True>])

# %%
# create an index
index_name_2 = "my-index-2"
dimension_2 = 1536
metric_2 = "euclidean"

# %%
# if index exist, delete it
if index_name_2 in [index.name for index in pc.list_indexes()]:
    pc.delete_index(index_name_2)
    print(f"{index_name_2} succesfully deleted.")
else:
    print(f"{index_name_2} not in index list.")
# Out:
# my-index-2 not in index list.

# %%
pc
# Out:
# Pinecone(api_key='...deLy', host='https://api.pinecone.io')

# %%
pc.create_index(
    name=index_name_2,
    dimension=dimension_2,
    metric=metric_2,
    spec=ServerlessSpec(
        cloud='aws',
        region='us-east-1'
    )
)
# Out:
# IndexModel(name='my-index-2', metric='euclidean', status=IndexStatus(ready=True, state='Ready'), spec=IndexSpec(serverless=ServerlessSpecInfo(cloud='aws', region='us-east-1', read_capacity={'mode': 'OnDemand', 'status': {'state': 'Ready', 'current_shards': None, 'current_replicas': None}}, source_collection=None, schema=None), pod=None, byoc=None), host='https://my-index-2-4l0pdu7.svc.aped-4627-b74a.pinecone.io', private_host=None, vector_type='dense', dimension=1536, deletion_protection='disabled', tags=None, embed=None, created_at=None)

# %%
if index_name_2 in [index.name for index in pc.list_indexes()]:
    pc.delete_index(index_name_2)
    print(f"{index_name_2} succesfully deleted.")
else:
    print(f"{index_name_2} not in index list.")
# Out:
# my-index-2 succesfully deleted.

# %%
index = pc.Index(name = index_name)

# %%
index
# Out:
# Index(host='https://my-index-4l0pdu7.svc.aped-4627-b74a.pinecone.io')

# %%
index.upsert(vectors=[
        ("Dog",[4.,0.,1.]),
        ("Cat",[4.,0.,1.]),
        ("Chicken",[2.,2.,1.]),
        ("Mantis",[6.,2.,3.]),
        ("Elephant",[4.,0.,1.])
])
# Out:
# UpsertResponse(upserted_count=5)
